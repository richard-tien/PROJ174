# %%
# %run initialising.ipynb
# %run statistical-analysis.ipynb
# %run histograms.ipynb
# %run box-plots.ipynb
# %run kde-plots.ipynb
# Out:
# Is the %accuracy of EX30 significantly different to LD30, when requested expansion > 2.0 mm?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Richard/Documents/OneDrive - The University of Western Australia/PROJ174/Data Analysis/PROJ174/statistical-analysis.ipynb in <module>()
#       1 for measure_type in MEASURE_TYPES:
# ----> 2     compare_ex30_vs_ld30(measure_type, THRESHOLD)
#
# /Users/Richard/Documents/OneDrive - The University of Western Australia/PROJ174/Data Analysis/PROJ174/statistical-analysis.ipynb in compare_ex30_vs_ld30(measure_type, threshold)
#      21             full_antimere = '%s%s-%s%s%s' % (i, toothNum, j, toothNum, measure_type)
#      22
# ---> 23             col1 = getColumn(df, '%s %%acc' % full_antimere, antimere, threshold, measure_type, 'EX30').dropna()
#      24             col2 = getColumn(df, '%s %%acc' % full_antimere, antimere, threshold, measure_type, 'LD30').dropna()
#      25
#
# TypeError: getColumn() takes from 4 to 5 positional arguments but 6 were given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Richard/Documents/OneDrive - The University of Western Australia/PROJ174/Data Analysis/PROJ174/histograms.ipynb in <module>()
#       1 for measure_type in MEASURE_TYPES:
# ----> 2     plotHistograms(df, 'EX30', measure_type)
#       3     plotHistograms(df, 'LD30', measure_type)
#
# /Users/Richard/Documents/OneDrive - The University of Western Australia/PROJ174/Data Analysis/PROJ174/histograms.ipynb in plotHistograms(df, aligner_material, measure_type)
#      22         plt.subplot(1, 2, 1)
#      23
# ---> 24         col1 = getColumn(df, '%s %%acc' % full_antimere, antimere, False, measure_type, aligner_material).dropna()
#      25         col1.hist(bins=10, facecolor='blue')
#      26         plt.title('%s %s\n%%acc\nmean=%s\nn=%s' % (aligner_material, full_antimere, col1.mean(), len(col1)))
#
# TypeError: getColumn() takes from 4 to 5 positional arguments but 6 were given

# %%
getColumn(df, '15-25.ctd %acc', 2, 'EX30')
# Out:
# Patient ID
# 1645196     34.512470
# 1654114     76.464017
# 1776637     81.473556
# 1809618     71.529013
# 1812712     52.439264
# 1821189     47.825333
# 1856705     35.166549
# 1857828     78.806985
# 1953074     57.428356
# 1955743     45.383432
# 1974079     47.055742
# 1982901     64.353274
# 2028257     41.278263
# 2103852     68.915358
# 2109635     90.711934
# 2171242     69.185739
# 2209074     66.436973
# 2232325     49.514388
# 2247967     59.839407
# 2252675     64.220328
# 2252538     44.648538
# 2268142     38.517008
# 2286253     63.857738
# 2294066   -162.634578
# 2314641     77.731706
# 2448128     49.829614
# 2525737     88.921711
# 2566774     63.207531
# 2650539     63.737632
# 2670212     63.524715
# 2696115     80.702537
# Name: 15-25.ctd %acc, dtype: float64
