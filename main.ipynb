# %%
# %run initialising.ipynb
# %run statistical-analysis.ipynb
# %run histograms.ipynb
# %run box-plots.ipynb
# %run kde-plots.ipynb
# Out:
# Is the %accuracy of EX30 significantly different to LD30, for any level of requested expansion?
# ---13-23.cc---
# EX30: mean=84.45529554077416	std=22.007283621757004	n=35
# LD30: mean=83.92010172924097	std=48.58964738668601	n=60
# p=0.951105035925
#
# ---14-24.cc---
# EX30: mean=77.0002796077631	std=24.674952281027686	n=35
# LD30: mean=82.17139040551989	std=21.27185940399557	n=60
# p=0.284291142497
#
# ---15-25.cc---
# EX30: mean=86.40827739532212	std=50.06209526675075	n=35
# LD30: mean=83.15753369210802	std=21.101924044726257	n=60
# p=0.659922672859
#
# ---16-26.cc---
# EX30: mean=77.60655720702897	std=67.52643556189217	n=35
# LD30: mean=95.10414986397852	std=48.96487273302111	n=60
# p=0.148481694224
#
# ---33-43.cc---
# EX30: mean=90.57819528539369	std=37.13043298885475	n=35
# LD30: mean=103.78081880873268	std=73.54164520873378	n=60
# p=0.324973055334
#
# ---34-44.cc---
# EX30: mean=90.94842523381652	std=73.00118491330132	n=34
# ...
